# %%
# %run ../run.py
# %matplotlib widget

# build
begin()

add_element(circle(pts[0], pts[1]))
add_element(circle(pts[1], pts[0]))

# render
limx, limy = (-2, 2), (-1.5, 1.5)
bounds = set_bounds(limx, limy)

plt_init(limx, limy)

plot_segment(pts[0], pts[1], color='#36c9', marker='')
# plot_polygon(polygon([pts[0], pts[1], pts[3]]))
plot_polygon(polygon_ids([0, 1, 3]))

plot_elements(elements, bounds)
plot_points(pts)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.cla()
plt_init(limx, limy)

add_element(line(pts[0], pts[1]))

add_element(line(pts[0], pts[2]))
add_element(line(pts[0], pts[3]))
add_element(line(pts[1], pts[2]))
add_element(line(pts[1], pts[3]))

plot_elements(elements, bounds)
plot_points(pts)

# %%
plot_polygon(polygon_ids([0, 1, 3]))
plot_polygon(polygon_ids([2, 8, 6]))

# %%
add_element(line(pts[2], pts[3]))
add_element(line(pts[0], pts[8]))
add_element(line(pts[1], pts[6]))

plot_elements(elements, bounds)
plot_points(pts)

# %%
c = add_element(circle(pts[14], pts[2]))
plot_circle(c)
plot_points(pts)

# %%
sg_pts = [pts[i] for i in [18, 0, 1, 19]]
p = polygon_ids([18, 0, 1, 19])

sgs = [segment(sg_pts[i], sg_pts[i+1]) for i in range(len(sg_pts)-1)]

for sg in sgs:
    plot_segment2(sg)
    
plot_points(pts)
