# %%
# %run run.py
# %matplotlib widget
import math as math

log_init('wedges')

begin_zero()

# add_element(line(pts[0], pts[1]))
add_element(circle(pts[0], pts[1]))

limx, limy = (-10, 10), (-25, 25)
bounds = set_bounds(limx, limy)

plt_init()

plot_elements(elements, bounds)
plot_points(pts)

theta = math.degrees(2 * np.pi / phi)


leafs=144
for i in range(0, leafs):
    plot_wedge_2(pts[0], leafs-i, theta*(i), theta*(i+1), linestyle='-', ec='#000', fc='#c903', linewidth=2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
