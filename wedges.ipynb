# %%
# %run run.py
# %matplotlib widget
import math as math

log_init('wedges')

begin_zero()

add_element(line(pts[0], pts[1]))
add_element(circle(pts[0], pts[1]))

limx, limy = (-10, 10), (-10, 10)
bounds = set_bounds(limx, limy)

plt_init(limx, limy)

plot_elements(elements, bounds)
plot_points(pts)

theta = math.degrees(2 * np.pi / phi)

for i in reversed(range(0, 10)):
    plot_wedge_2(pts[0], i, theta*(i-1), theta*i, linestyle='-', ec='#000', fc='#F0F', linewidth=2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
