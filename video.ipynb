# %%
import glob, os
os.chdir("/home/phi/Notebooks/geometor-explorer/out/inferno")
with open('list.txt', 'w') as f:

    for file in sorted(glob.glob("inferno-1220-0002-*.png")):
        f.write(f'file {file}\n')
        # f.write(f'duration .125\n')


! cat list.txt
# Out:
# file inferno-1220-0002-0001.png
# file inferno-1220-0002-0002.png
# file inferno-1220-0002-0003.png
# file inferno-1220-0002-0004.png
# file inferno-1220-0002-0005.png
# file inferno-1220-0002-0006.png
# file inferno-1220-0002-0007.png
# file inferno-1220-0002-0008.png
# file inferno-1220-0002-0009.png
# file inferno-1220-0002-0010.png
# file inferno-1220-0002-0011.png
# file inferno-1220-0002-0012.png
# file inferno-1220-0002-0013.png
# file inferno-1220-0002-0014.png
# file inferno-1220-0002-0015.png
# file inferno-1220-0002-0016.png
# file inferno-1220-0002-0017.png
# file inferno-1220-0002-0018.png
# file inferno-1220-0002-0019.png
# file inferno-1220-0002-0020.png
# file inferno-1220-0002-0021.png
# file inferno-1220-0002-0022.png
# file inferno-1220-0002-0023.png
# file inferno-1220-0002-0024.png
# file inferno-1220-0002-0025.png
# file inferno-1220-0002-0026.png
# file inferno-1220-0002-0027.png
# file inferno-1220-0002-0028.png
# file inferno-1220-0002-0029.png
# ...

# %%
! rm list.mp4
# ! ffmpeg -r 8 -f concat -i list.txt list.mp4
! ffmpeg  -f concat -i list.txt -c:v libx264 -pix_fmt yuv420p -movflags +faststart list.mp4


# !mpv -fs -loop=yes list.mp4
# Out:
# ffmpeg version 4.3.2-0+deb11u1ubuntu1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10 (Ubuntu 10.2.1-20ubuntu1)
# ...
