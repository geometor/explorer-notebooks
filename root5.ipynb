# %%
# %run run.py
# %matplotlib widget
log_init('root5')

# %%
start_time = timer()

begin()

bisector(pts[0], pts[1])
bisector(pts[0], pts[3])
bisector(pts[1], pts[2])

# root5 diagonal
add_element(line(pts[18], pts[31]))
add_element(circle(pts[6], pts[0]))
add_element(circle(pts[6], pts[18]))

# outer goldens
el = add_element(circle(pts[0], pts[50]))
el = add_element(circle(pts[1], pts[49]))

# inner goldens
# el = add_element(circle(pts[0], pts[49]))
# el = add_element(circle(pts[1], pts[50]))

# star diagonals
# el = add_element(line(pts[0], pts[61]))
# el = add_element(line(pts[1], pts[77]))

print(f'Build: {elapsed(start_time)}')
print()
print(f'elements: {len(elements)}')
print(f'  points: {len(pts)}')
# Out:
# Build: 0:00:03.013474
#
# elements: 15
#   points: 91

# %%
start_time = timer()

limx, limy = (-3.5, 3.5), (-2.5, 2.5)
bounds = set_bounds(limx, limy)

plt_init(limx, limy)

sgs = []
sgs.append(plot_segment(pts[49], pts[0]))
sgs.append(plot_segment(pts[0], pts[1]))
sgs.append(plot_segment(pts[1], pts[50]))

# sg = plot_segment(pts[61], pts[77])

pentagon = polygon_ids([0, 1, 59, 61, 77])
plot_polygon(pentagon, color='#3C03')

pentagon = polygon_ids([0, 1, 60, 62, 78])
plot_polygon(pentagon, color='#3C03')

square = unit_square(pts[0])
add_points(square.vertices)
plot_polygon(square)

square = unit_square(pts[31])
add_points(square.vertices)
plot_polygon(square)

plot_elements(elements, bounds)
plot_points(pts)

print(f'Render: {elapsed(start_time)}')
# Out:
# Render: 0:00:00.869998
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
[sp.simplify(s.length) for s in pentagon.sides]
# Out:
# ⎡         _________________________________________     _________________________________________   ⎤
# ⎢        ╱        ________   __________                ╱        ________   __________               ⎥
# ⎢      ╲╱  - √2⋅╲╱ √5 + 5 ⋅╲╱ 2⋅√5 + 5  + 3⋅√5 + 9   ╲╱  - √2⋅╲╱ √5 + 5 ⋅╲╱ 2⋅√5 + 5  + 3⋅√5 + 9    ⎥
# ⎢1, 1, ────────────────────────────────────────────, ────────────────────────────────────────────, 1⎥
# ⎣                           2                                             2                         ⎦

# %%
sp.simplify(pentagon.sides[2].length - 1)
# Out:
# 0

# %%
pentagon.sides[2].length.equals
# Out:
# <bound method Expr.equals of sqrt((-sqrt(sqrt(5)/8 + 5/8) + sqrt(sqrt(5)/2 + 5/4))**2 + (1/4 + sqrt(5)/4)**2)>

# %%
sg_ratio = (sgs[0] / sgs[1])
sg_ratio.evalf()
# Out:
# 0.618033988749895

# %%
(sgs[0]).simplify(), (sgs[1]**2).simplify()
# Out:
# ⎛  1   √5   ⎞
# ⎜- ─ + ──, 1⎟
# ⎝  2   2    ⎠

# %%
(sg_ratio - phi).simplify()
# Out:
# -1

# %%
(sg_ratio * phi).simplify()
# Out:
# 1

# %%
sp.srepr(pts[77])
# Out:
# 'Point2D(Add(Mul(Integer(-1), Rational(1, 4), Pow(Integer(5), Rational(1, 2))), Rational(-1, 4)), Pow(Add(Mul(Rational(1, 8), Pow(Integer(5), Rational(1, 2))), Rational(5, 8)), Rational(1, 2)))'

# %%
elements[1].bounds
# Out:
# (-3/2, -1, 1/2, 1)

# %%
pts[4].y > pts[5].y
# Out:
# False

# %%
lines = [el for el in elements if type(el) is sp.Circle]

# %%
len(lines)
# Out:
# 10
