# %%
from sympy.solvers import solve
from sympy import Symbol
from sympy.plotting import plot
from sympy.plotting import plot_implicit
# %matplotlib notebook

x = Symbol('x')
y = Symbol('y')


expr = x**2 - x - 1
roots = solve(expr)
roots[0]**2
# print(len(roots))
# roots.count(0)
# roots.count
# Out:
# (1/2 - sqrt(5)/2)**2

# %%
p = plot(expr, (x, -3, 3), show=False, aspect_ratio=(1,1))
p.ylim=(-2, 2)

# %%
p.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# p.extend(plot(x+1))
# p.draw()
p.
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_380572/2151779125.py in <module>
#       1 p.extend(plot(x+1))
# ----> 2 p.draw()
#
# AttributeError: 'Plot' object has no attribute 'draw'
