# %%
from sympy.solvers import solve
from sympy import Symbol
from sympy.plotting import plot
from sympy.plotting import plot_implicit
# %matplotlib notebook

x = Symbol('x')
y = Symbol('y')


expr = x**2 - x - 1
roots = solve(expr)
roots[0]**2
# print(len(roots))
# roots.count(0)
# roots.count
# Out:
# (1/2 - sqrt(5)/2)**2

# %%
p = plot(expr, (x, -4, 4), show=False, aspect_ratio=(1,1))
p.ylim=(-2, 2)

# %%
p.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
p2 = plot(x + 1, (x, -4, 4), show=False, aspect_ratio=(1,1))
# p2.xlim = (-3, 3)
p2.ylim = (-2, 2)
p.extend(p2)
p.xlim = (-3, 3)
from matplotlib import style
style.use('dark_background')

p.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
style?

# %%
style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']
