# %%
# %run lib/setup6.py
# %matplotlib notebook
log_init('kepler')

# %%
start_time = timer()

pt_a = add_point(point(0, 0))
pt_b = add_point(point(1, 0))
pt_c = add_point(point(0, sp.sqrt(Φ)))

bisector(pt_a, pt_b)
bisector(pt_a, pt_c)
# bisector(pt_b, pt_c)

# circumcircle
add_element(circle(pts[29], pt_a))

print(f'Build: {elapsed(start_time)}')
print()
print(f'elements: {len(elements)}')
print(f'  points: {len(pts)}')
# Out:
# Build: 0:00:05.240054
#
# elements: 9
#   points: 40

# %%
start_time = timer()

limx, limy = (-2, 4), (-2, 2)
bounds = set_bounds(limx, limy)

plt_init(limx, limy)

plot_segment(pt_a, pt_b)
plot_segment(pt_b, pt_c)
plot_segment(pt_c, pt_a)

plot_elements(elements, bounds)
plot_points(pts)

print(f'Render: {elapsed(start_time)}')
# Out:
# <img src="data:image/png;base64,..." width="840">
# Render: 0:00:01.907612

# %%
pts[29]
# Out:
# Point2D(1/2, -3*GoldenRatio**(3/2)/4 - 3*GoldenRatio/4 - 1/2 - sqrt(GoldenRatio)/4 + GoldenRatio**2/4 + GoldenRatio**3/4 + 3*GoldenRatio**(5/2)/4)

# %%
(pts[29].y.simplify() - (sp.sqrt(phi)/4)).simplify()
# Out:
#      3/2                       ________    2    3      5/2
#   3⋅φ      3⋅φ   1   √φ   √2⋅╲╱ 1 + √5    φ    φ    3⋅φ
# - ────── - ─── - ─ - ── - ───────────── + ── + ── + ──────
#     4       4    2   4          8         4    4      4

# %%
sqp = sp.sqrt(phi) 
sqp / 2
# Out:
#     ________
#    ╱ 1   √5
#   ╱  ─ + ──
# ╲╱   2   2
# ────────────
#      2

# %%
(pts[29].y).evalf()
# Out:
# 0.636009824757034

# %%
(sqp / 2).evalf()
# Out:
# 0.636009824757034
