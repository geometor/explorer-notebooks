# %%
# %run run.py
# %matplotlib widget
log_init('kepler')

start_time = timer()

pt_a = add_point(point(0, 0))
pt_b = add_point(point(1, 0))
#this point should be constructed eventually
pt_c = add_point(point(0, sp.sqrt(phi)))

bisector(pt_a, pt_b)
bisector(pt_a, pt_c)
bisector(pt_b, pt_c)

# circumcircle
c = add_element(circle(pts[30], pt_a))

print(f'Build: {elapsed(start_time)}')
print()
print(f'elements: {len(elements)}')
print(f'  points: {len(pts)}')
# Out:
# Build: 0:00:06.013655
#
# elements: 13
#   points: 84

# %%
start_time = timer()

limx, limy = (-2, 4), (-2, 2)
bounds = set_bounds(limx, limy)

plt_init(limx, limy)

triangle = polygon([pt_a, pt_b, pt_c])

plot_polygon(triangle, color='#fc03')

# plot_segment(pt_a, pt_b)
# plot_segment(pt_b, pt_c)
# plot_segment(pt_c, pt_a)

plot_elements(elements, bounds)
plot_circle(c, color='#fc0', linestyle='-')

plot_points(pts)

print(f'Render: {elapsed(start_time)}')
# Out:
# Render: 0:00:03.056689
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
val = pts[24].y

# %%
val.simplify()
# Out:
#   __________
# ╲╱ 2 + 2⋅√5
# ────────────
#      4

# %%
val.expand()
# Out:
#   __________
# ╲╱ 2 + 2⋅√5
# ────────────
#      4

# %%
val.factor()
# Out:
#      ________
# √2⋅╲╱ 1 + √5
# ─────────────
#       4

# %%
(pts[29].y.simplify() - (sp.sqrt(phi)/4)).simplify()
# Out:
#   __________
# ╲╱ 2 + 2⋅√5
# ────────────
#      8

# %%
sqp = sp.sqrt(phi) 
sqp / 2
# Out:
#     ________
#    ╱ 1   √5
#   ╱  ─ + ──
# ╲╱   2   2
# ────────────
#      2

# %%
(pts[29].y).evalf()
# Out:
# 0.636009824757034

# %%
(sqp / 2).evalf()
# Out:
# 0.636009824757034

# %%
for el in reversed(elements):
    print(f'check {el}')
    for check in elements:
        diff = 
        print(
        # if el.are_concurrent(check):
        #     print(f' {el} & {check} are concurrent')
# Out:
#   File "/tmp/ipykernel_913891/1000619061.py", line 4
#     diff =
#            ^
# SyntaxError: invalid syntax
