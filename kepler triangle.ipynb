# %%
# %run lib/setup4.py
# %matplotlib notebook

limx = (-1, 2)
limy = (-1, 2)
bounds = sp.Polygon(
    point(limx[0], limy[1]),
    point(limx[0], limy[0]),
    point(limx[1], limy[0]),
    point(limx[1], limy[1])
)

# %%
mpp_init(limx, limy)
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
pt_a = add_point(point(0, 0))
pt_b = add_point(point(1, 0))
pt_c = add_point(point(0, sp.sqrt(Φ)))


plot_segment(pt_a, pt_b)
plot_segment(pt_b, pt_c)
plot_segment(pt_c, pt_a)

bisector(pt_a, pt_b, bounds)
bisector(pt_a, pt_c, bounds)
bisector(pt_b, pt_c, bounds)

plot_points()

# %%
len(pts)
# Out:
# 77

# %%
[(pt.x.simplify(), pt.y.simplify()) for pt in pts[5:6]]
# Out:
# ⎡⎛     -√3 ⎞⎤
# ⎢⎜1/2, ────⎟⎥
# ⎣⎝      2  ⎠⎦

# %%
(pt_c.distance(pt_b) - Φ).simplify()
# Out:
# 0

# %%
sp.sqrt(Φ).evalf()
# Out:
# 1.27201964951407
