# %%
# %run lib/setup5.py
# %matplotlib notebook

limx = (-3, 3)
limy = (-2.5, 2.5)
bounds = sp.Polygon(
    point(limx[0], limy[1]),
    point(limx[0], limy[0]),
    point(limx[1], limy[0]),
    point(limx[1], limy[1])
)

plt_init(limx, limy)

begin()

bisector(pts[0], pts[1], bounds)
bisector(pts[0], pts[3], bounds)
bisector(pts[1], pts[2], bounds)

# mpp.plot([-.5, .5], [0,0], color='#fc09', linestyle='-', linewidth=3, marker='o')  
plot_segment(pts[0], pts[1])

plot_points()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
pts[12]
# Out:
# Point2D(-1/4, sqrt(15)/4)
