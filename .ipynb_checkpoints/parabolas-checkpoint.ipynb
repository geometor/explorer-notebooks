# %%
# %run lib/setup6.py
# %matplotlib widget
# %pdb
log_init('vesica')

# Build
start_time = timer()

begin_zero()

bisector(pts[0], pts[1])



expr = x**2 - x - 1
roots = sp.solve(expr)
pr = [point(root, 0) for root in roots]
for pt in pr:
    add_point(pt)

# %% [markdown]
# trying to marry sympy and matplotlib

# %%
limx, limy = (-3.5, 3.5), (-2.5, 2.5)
bounds = set_bounds(limx, limy)

plt_init(limx, limy)

ax.spines['left'].set_color('red') 

p = spp.plot(expr, aspect_ratio=(1,1), show=False)
# p = spp.plot(expr, (x, -3, 4), (y, -2, 4), aspect_ratio=(1,1), show=False)
p.xlim = limx
p.ylim = limy

p.show()

plot_elements(elements, bounds)
plot_points(pts)

# p.show()

print(f'Render: {elapsed(start_time)}')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Render: 0:04:35.764301

# %%
plot_segment(pts[7], pts[8])
# Out:
# √5
