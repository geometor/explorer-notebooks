# %% [markdown]
# Pappus Line Generator
#
# - set three points on two lines
# - join corresponding pairs of points
# - the meets of joins will fall on a line

# %%
# %run run.py
from geometor.pappus import *
from itertools import permutations

# %matplotlib widget
plt.rcParams['figure.figsize'] = [8, 8]

for perm_id in range(6):
    print('PERMUTATION: ', perm_id)
    print()
    pts.clear()
    elements.clear()

    A = []
    A.append( add_point( point(0, 0, classes=['A', 'square']) ) )
    A.append( add_point( point(1, 0, classes=['A', 'circle']) ) )
    line_a = line(A[0], A[1], classes=['blue']) 
    add_element(line_a)
    x_val = 3
    A.append( add_point( point(x_val, 0, classes=['A', 'diamond']) ) )
    line_a.pts.append(A[-1])

    B = []
    B.append( add_point( point(0, 1, classes=['B']) ) )
    B.append( add_point( point(1, 2, classes=['B']) ) )
    line_b = line(B[0], B[1], classes=['blue']) 
    add_element(line_b)
    x_val = 3
    y_val = line_get_y(line_b, x_val)
    B.append( add_point( point(x_val, y_val, classes=['B']) ) )
    line_b.pts.append(B[-1])

    B_perms = list(permutations(B))

    # perm_id = 0
    B = B_perms[perm_id]

    # set classes for B points
    # print('B points:')
    for i, pt in enumerate(B):
        pt.classes.append(types[i])
        # print(i, pt, pt.classes)


    set_meet(0, 1, A, B)
    set_meet(1, 2, A, B)
    set_meet(2, 0, A, B)

    meets = get_pts_by_class('meet')

    if len(meets) >= 2:
        pappus_line = line(meets[0], meets[1], classes=['blue', 'pappus'])
        add_element(pappus_line)
    else:
        print('no pappus line')
    if len(meets) == 3:
        pappus_line.pts.append(meets[2])
        print('collinear: ', sp.Point.is_collinear(*meets))


    # initialize plot
    limx, limy = get_limits_from_points(pts)
    bounds = set_bounds(limx, limy)

    plt.style.use('dark_background')
    plt.cla()
    # fig, ax = plt.subplots()

    # plt.figure(num=1, figsize=(10.0, 8.0), dpi=150)
    plt.gca().set_aspect('equal')

    # if limx:
    #     plt.gca().set_xlim(limx[0], limx[1])
    # if limy:
    #     plt.gca().set_ylim(limy[0], limy[1])

    title = f'G E O M E T O R • pappus • perm: {perm_id}'
    plt.gca().set_title(title, fontdict={'color': '#960', 'size':'small'})
    plt.axis(False)
    plt.tight_layout()

    plot_elements(elements, bounds)

    plot_points(get_pts_by_class('circle'), **classes['circle'], add_to_cursors=False)
    plot_points(get_pts_by_class('square'), **classes['square'], add_to_cursors=False)
    plot_points(get_pts_by_class('diamond'), **classes['diamond'], add_to_cursors=False)
    plot_points(pts)

    filename = f'pappus/line-{perm_id}.png'
    plt.savefig(filename, dpi=300)

    print(f'\ntriangles: ')

    triangle_sq = polygon(get_pts_by_class('square'))
    print(f'    squares:')
    if isinstance(triangle_sq, spg.Triangle):
        plot_polygon(triangle_sq, color='#FF03')
        print(f'        area: {triangle_sq.area}')
        print(f'       perim: {triangle_sq.perimeter}')
    else:
        plot_segment2(triangle_sq, color='#FF09', marker='')

    triangle_cir = polygon(get_pts_by_class('circle'))
    print(f'    circle:')
    if isinstance(triangle_cir, spg.Triangle):
        plot_polygon(triangle_cir, color='#0FF3')
        print(f'        area: {triangle_cir.area}')
        print(f'       perim: {triangle_cir.perimeter}')
    else:
        plot_segment2(triangle_cir, color='#0FF9', marker='')

    triangle_dia = polygon(get_pts_by_class('diamond'))
    print(f'    diamond:')
    if isinstance(triangle_dia, spg.Triangle):
        plot_polygon(triangle_dia, color='#F0F3')
        print(f'        area: {triangle_dia.area}')
        print(f'       perim: {triangle_dia.perimeter}')
    else:
        plot_segment2(triangle_dia, color='#F0F9', marker='')

    filename = f'pappus/line-{perm_id}-tri.png'
    plt.savefig(filename, dpi=300)


    print(f'\npoints: ', len(pts))
    for pt in pts:
        print(f'    {str(pt.x): >8} {str(pt.y): >8} {pt.classes} {[el.coefficients for el in pt.parents]}')
    print(f'\nelements: ', len(elements))
    for el in elements:
        print(f'    {el.coefficients} {el.classes} ')
        
    print()
    print('***************')
# Out:
# PERMUTATION:  0
#
# join 0 1
#   j1: (-2, 1, 0)
#   j2: (-1, -1, 1)
#   spread: 9/10
#   meet (1/3, 2/3)
# join 1 2
#   j1: (-4, 2, 4)
#   j2: (-2, -2, 6)
#   spread: 9/10
#   meet (5/3, 4/3)
# join 2 0
#   j1: (-1, -3, 3)
#   j2: (-4, 3, 0)
#   spread: 25/34
#   meet (3/5, 4/5)
# collinear:  True
#
# triangles:
#     squares:
#         area: -5/6
#        perim: 1 + sqrt(26)/3 + sqrt(41)/3
#     circle:
#         area: 2/5
#        perim: 2*sqrt(5)/5 + 2*sqrt(10)/5 + 2
#     diamond:
#         area: 16/3
#        perim: 2*sqrt(17)/3 + 4 + 2*sqrt(41)/3
#
# points:  14
#            0        0 ['A', 'square'] []
#            1        0 ['A', 'circle'] []
#            3        0 ['A', 'diamond'] []
#            0        1 ['B', 'square'] []
#            1        2 ['B', 'circle'] []
#           -1        0 [] [(-1, 1, -1), (0, 1, 0)]
#            3        4 ['B', 'diamond'] []
#          1/3      2/3 ['meet', 'diamond'] [(-1, -1, 1), (-2, 1, 0)]
#          5/3      4/3 ['meet', 'square'] [(-2, -2, 6), (-4, 2, 4)]
#          3/7      6/7 [] [(-1, -3, 3), (-2, 1, 0)]
#          9/7      4/7 [] [(-1, -3, 3), (-4, 2, 4)]
#          3/7      4/7 [] [(-4, 3, 0), (-1, -1, 1)]
#          9/7     12/7 [] [(-4, 3, 0), (-2, -2, 6)]
#          3/5      4/5 ['meet', 'circle'] [(-4, 3, 0), (-1, -3, 3)]
#
# elements:  9
#     (0, 1, 0) ['blue']
#     (-1, 1, -1) ['blue']
#     (-2, 1, 0) ['red']
#     (-1, -1, 1) ['green']
#     (-4, 2, 4) ['red']
#     (-2, -2, 6) ['green']
#     (-1, -3, 3) ['red']
#     (-4, 3, 0) ['green']
#     (-2/3, 4/3, -2/3) ['blue', 'pappus']
#
# ***************
# PERMUTATION:  1
#
# join 0 1
#   j1: (-4, 3, 0)
#   j2: (-1, -1, 1)
#   spread: 49/170
#   meet (3/7, 4/7)
# join 1 2
#   j1: (1, 0, -1)
#   j2: (1, 0, -3)
#   spread: nan
# join 2 0
#   j1: (-1, -3, 3)
#   j2: (-2, 1, 0)
#   spread: 49/50
#   meet (3/7, 6/7)
#
# triangles:
#     squares:
#     circle:
#         area: 2
#        perim: 2*sqrt(13)/7 + 2*sqrt(202)/7 + 2*sqrt(5)
#     diamond:
#         area: 2
#        perim: 2*sqrt(29)/7 + 2*sqrt(85)/7 + 2*sqrt(2)
#
# points:  17
#            0        0 ['A', 'square'] []
#            1        0 ['A', 'circle'] []
#            3        0 ['A', 'diamond'] []
#            0        1 ['B', 'square'] []
#            1        2 ['B', 'diamond'] []
#           -1        0 [] [(-1, 1, -1), (0, 1, 0)]
#            3        4 ['B', 'circle'] []
#          3/7      4/7 ['meet', 'diamond'] [(-1, -1, 1), (-4, 3, 0)]
#            1      4/3 [] [(1, 0, -1), (-4, 3, 0)]
#            3       -2 [] [(1, 0, -3), (-1, -1, 1)]
#          3/5      4/5 [] [(-1, -3, 3), (-4, 3, 0)]
#            1      2/3 [] [(-1, -3, 3), (1, 0, -1)]
#          1/3      2/3 [] [(-2, 1, 0), (-1, -1, 1)]
#            3        6 [] [(-2, 1, 0), (1, 0, -3)]
#          3/7      6/7 ['meet', 'circle'] [(-2, 1, 0), (-1, -3, 3)]
#          3/7        0 [] [(1, 0, -3/7), (0, 1, 0)]
#          3/7     10/7 [] [(1, 0, -3/7), (-1, 1, -1)]
#
# elements:  9
#     (0, 1, 0) ['blue']
#     (-1, 1, -1) ['blue']
#     (-4, 3, 0) ['red']
#     (-1, -1, 1) ['green']
#     (1, 0, -1) ['red']
#     (1, 0, -3) ['green']
#     (-1, -3, 3) ['red']
#     (-2, 1, 0) ['green']
#     (1, 0, -3/7) ['blue', 'pappus']
#
# ***************
# PERMUTATION:  2
#
# join 0 1
#   j1: (1, 0, 0)
#   j2: (1, 0, -1)
#   spread: nan
# join 1 2
#   j1: (-4, 2, 4)
#   j2: (-1, -3, 3)
#   spread: 196/221
#   meet (9/7, 4/7)
# join 2 0
#   j1: (-2, -2, 6)
#   j2: (-4, 3, 0)
#   spread: 49/65
#   meet (9/7, 12/7)
#
# triangles:
#     squares:
#         area: -1
#        perim: sqrt(97)/7 + 2*sqrt(26)/7 + sqrt(5)
#     circle:
#         area: -1
#        perim: sqrt(2) + sqrt(106)/7 + 2*sqrt(37)/7
#     diamond:
#
# points:  17
#            0        0 ['A', 'square'] []
#            1        0 ['A', 'circle'] []
#            3        0 ['A', 'diamond'] []
#            0        1 ['B', 'circle'] []
#            1        2 ['B', 'square'] []
#           -1        0 [] [(-1, 1, -1), (0, 1, 0)]
#            3        4 ['B', 'diamond'] []
#            0       -2 [] [(-4, 2, 4), (1, 0, 0)]
#            1      2/3 [] [(-1, -3, 3), (1, 0, -1)]
#          9/7      4/7 ['meet', 'square'] [(-1, -3, 3), (-4, 2, 4)]
#            0        3 [] [(-2, -2, 6), (1, 0, 0)]
#          5/3      4/3 [] [(-2, -2, 6), (-4, 2, 4)]
#            1      4/3 [] [(-4, 3, 0), (1, 0, -1)]
#          3/5      4/5 [] [(-4, 3, 0), (-1, -3, 3)]
#          9/7     12/7 ['meet', 'circle'] [(-4, 3, 0), (-2, -2, 6)]
#          9/7        0 [] [(1, 0, -9/7), (0, 1, 0)]
#          9/7     16/7 [] [(1, 0, -9/7), (-1, 1, -1)]
#
# elements:  9
#     (0, 1, 0) ['blue']
#     (-1, 1, -1) ['blue']
#     (1, 0, 0) ['red']
#     (1, 0, -1) ['green']
#     (-4, 2, 4) ['red']
#     (-1, -3, 3) ['green']
#     (-2, -2, 6) ['red']
#     (-4, 3, 0) ['green']
#     (1, 0, -9/7) ['blue', 'pappus']
#
# ***************
# PERMUTATION:  3
#
# join 0 1
#   j1: (-4, 3, 0)
#   j2: (1, 0, -1)
#   spread: 1/17
#   meet (1, 4/3)
# join 1 2
#   j1: (-1, -1, 1)
#   j2: (1, 0, -3)
#   spread: 1/2
#   meet (3, -2)
# join 2 0
#   j1: (-2, -2, 6)
#   j2: (1, 0, 0)
#   spread: 1/5
#   meet (0, 3)
# collinear:  True
#
# triangles:
#     squares:
#         area: -4
#        perim: sqrt(13) + 3*sqrt(5)
#     circle:
#         area: 5
#        perim: 2*sqrt(5) + 2*sqrt(10)
#     diamond:
#         area: -1
#        perim: 2*sqrt(13)/3 + 4*sqrt(10)/3
#
# points:  14
#            0        0 ['A', 'square'] []
#            1        0 ['A', 'circle'] []
#            3        0 ['A', 'diamond'] []
#            0        1 ['B', 'diamond'] []
#            1        2 ['B', 'square'] []
#           -1        0 [] [(-1, 1, -1), (0, 1, 0)]
#            3        4 ['B', 'circle'] []
#            1      4/3 ['meet', 'diamond'] [(1, 0, -1), (-4, 3, 0)]
#          3/7      4/7 [] [(-1, -1, 1), (-4, 3, 0)]
#            3       -2 ['meet', 'square'] [(1, 0, -3), (-1, -1, 1)]
#          9/7     12/7 [] [(-2, -2, 6), (-4, 3, 0)]
#            0        3 ['meet', 'circle'] [(1, 0, 0), (-2, -2, 6)]
#          9/5        0 [] [(10/3, 2, -6), (0, 1, 0)]
#          3/4      7/4 [] [(10/3, 2, -6), (-1, 1, -1)]
#
# elements:  9
#     (0, 1, 0) ['blue']
#     (-1, 1, -1) ['blue']
#     (-4, 3, 0) ['red']
#     (1, 0, -1) ['green']
#     (-1, -1, 1) ['red']
#     (1, 0, -3) ['green']
#     (-2, -2, 6) ['red']
#     (1, 0, 0) ['green']
#     (10/3, 2, -6) ['blue', 'pappus']
#
# ***************
# PERMUTATION:  4
#
# join 0 1
#   j1: (1, 0, 0)
#   j2: (-4, 2, 4)
#   spread: 1/17
#   meet (0, -2)
# join 1 2
#   j1: (1, 0, -1)
#   j2: (-1, -3, 3)
#   spread: 1/2
#   meet (1, 2/3)
# join 2 0
#   j1: (1, 0, -3)
#   j2: (-2, 1, 0)
#   spread: 1/5
#   meet (3, 6)
# collinear:  True
#
# triangles:
#     squares:
#         area: -1
#        perim: sqrt(13)/3 + 2*sqrt(34)/3 + 5
#     circle:
#         area: -4
#        perim: sqrt(2) + sqrt(34) + 2*sqrt(10)
#     diamond:
#         area: 5
#        perim: 2*sqrt(2) + sqrt(13) + sqrt(17)
#
# points:  14
#            0        0 ['A', 'square'] []
#            1        0 ['A', 'circle'] []
#            3        0 ['A', 'diamond'] []
#            0        1 ['B', 'circle'] []
#            1        2 ['B', 'diamond'] []
#           -1        0 [] [(-1, 1, -1), (0, 1, 0)]
#            3        4 ['B', 'square'] []
#            0       -2 ['meet', 'diamond'] [(-4, 2, 4), (1, 0, 0)]
#          9/7      4/7 [] [(-1, -3, 3), (-4, 2, 4)]
#            1      2/3 ['meet', 'square'] [(-1, -3, 3), (1, 0, -1)]
#          3/7      6/7 [] [(-2, 1, 0), (-1, -3, 3)]
#            3        6 ['meet', 'circle'] [(-2, 1, 0), (1, 0, -3)]
#          3/4        0 [] [(-8/3, 1, 2), (0, 1, 0)]
#          9/5     14/5 [] [(-8/3, 1, 2), (-1, 1, -1)]
#
# elements:  9
#     (0, 1, 0) ['blue']
#     (-1, 1, -1) ['blue']
#     (1, 0, 0) ['red']
#     (-4, 2, 4) ['green']
#     (1, 0, -1) ['red']
#     (-1, -3, 3) ['green']
#     (1, 0, -3) ['red']
#     (-2, 1, 0) ['green']
#     (-8/3, 1, 2) ['blue', 'pappus']
#
# ***************
# PERMUTATION:  5
#
# join 0 1
#   j1: (-2, 1, 0)
#   j2: (-4, 2, 4)
#   spread: 0
# join 1 2
#   j1: (-1, -1, 1)
#   j2: (-2, -2, 6)
#   spread: 0
# join 2 0
#   j1: (1, 0, -3)
#   j2: (1, 0, 0)
#   spread: nan
# no pappus line
#
# triangles:
#     squares:
#     circle:
#     diamond:
#
# points:  13
#            0        0 ['A', 'square'] []
#            1        0 ['A', 'circle'] []
#            3        0 ['A', 'diamond'] []
#            0        1 ['B', 'diamond'] []
#            1        2 ['B', 'circle'] []
#           -1        0 [] [(-1, 1, -1), (0, 1, 0)]
#            3        4 ['B', 'square'] []
#          1/3      2/3 [] [(-1, -1, 1), (-2, 1, 0)]
#          5/3      4/3 [] [(-2, -2, 6), (-4, 2, 4)]
#            3        6 [] [(1, 0, -3), (-2, 1, 0)]
#            3       -2 [] [(1, 0, -3), (-1, -1, 1)]
#            0       -2 [] [(1, 0, 0), (-4, 2, 4)]
#            0        3 [] [(1, 0, 0), (-2, -2, 6)]
#
# elements:  8
#     (0, 1, 0) ['blue']
#     (-1, 1, -1) ['blue']
#     (-2, 1, 0) ['red']
#     (-4, 2, 4) ['green']
#     (-1, -1, 1) ['red']
#     (-2, -2, 6) ['green']
#     (1, 0, -3) ['red']
#     (1, 0, 0) ['green']
#
# ***************
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
elements
# Out:
# [Line2D(Point2D(0, 0), Point2D(1, 0)), Line2D(Point2D(0, 1), Point2D(1, 2)), Line2D(Point2D(0, 0), Point2D(1, 2)), Line2D(Point2D(1, 0), Point2D(0,
#  1)), Line2D(Point2D(1, 0), Point2D(3, 4)), Line2D(Point2D(3, 0), Point2D(1, 2)), Line2D(Point2D(3, 0), Point2D(0, 1)), Line2D(Point2D(0, 0), Point
# 2D(3, 4)), Line2D(Point2D(1/3, 2/3), Point2D(5/3, 4/3))]
