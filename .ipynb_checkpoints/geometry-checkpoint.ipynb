# %%
# %run geometor.py
# %matplotlib notebook

# %%
pts = []
pts.append(point(sp.Rational(-1, 2), 0))
pts.append(point(sp.Rational(1, 2), 0))
pts
# Out:
# [Point2D(-1/2, 0), Point2D(1/2, 0)]

# %%
elements = []
l1 = line(pts[0], pts[1])
c1 = circle(pts[0], pts[1])
c2 = circle(pts[1], pts[0])
c2.equation()
# Out:
# y**2 + (x - 1/2)**2 - 1

# %%
c1.equation()
# Out:
# y**2 + (x + 1/2)**2 - 1

# %%
p = spp.plot_implicit(c2, (x, -2, 2), (y, -2, 2), line_color='g', show=False)
p.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_392413/2623229198.py in <module>
#       1 p = spp.plot_implicit(c2, (x, -2, 2), (y, -2, 2), line_color='g', show=False)
# ----> 2 p.show()
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/plotting/plot.py in show(self)
#     235             self._backend.close()
#     236         self._backend = self.backend(self)
# --> 237         self._backend.show()
#     238
#     239     def save(self, path):
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/plotting/plot.py in show(self)
#    1521
#    1522     def show(self):
# -> 1523         self.process_series()
#    1524         #TODO after fixing https://github.com/ipython/ipython/issues/1255
#    1525         # you can uncomment the next line and remove the pyplot.show() call
#
# ...

# %%
g.plot.extend(g.plot(c1, 'r'))
plot.extend(g.plot(c2, 'r'))
pts.extend(c1.intersection(c2))
pts
g.plot.show()

# %%
l2 = g.line(pts[0], g.point(1, 1))
l2.equation()

# %%
plot = g.plot(l2, 'b')
plot.show()

# %%
p1 = spp.plot_implicit(c1.equation(), aspect_ratio=(1,1), show=False, line_color='r', axis=False, title='c1 & c2')
p1.xlim=(-2, 2)
p1.ylim=(-2, 2)
p2 = spp.plot_implicit(c2.equation(), aspect_ratio=(1,1), show=False, line_color='g')
p2.xlim=(-2, 2)
p2.ylim=(-2, 2)
p1.extend(p2)
p1.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
spp.plot(?)
# Out:
#   File "/tmp/ipykernel_392413/3538177955.py", line 1
#     spp.plot(?)
#              ^
# SyntaxError: invalid syntax
