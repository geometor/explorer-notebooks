# %%
# %run ../run.py
# %matplotlib widget

# build
begin_zero()
add_element(line(pts[0], pts[1]))

square = unit_square(pts[0])
add_points(square.vertices)
add_point(square.sides[0].midpoint)
radius = segment(pts[-1], pts[2])

# plot
limx, limy = (-1, 2), (-2, 2)
bounds = set_bounds(limx, limy)
plt_init(limx, limy)

plot_polygon(square)

plot_elements(elements, bounds)
plot_points(pts)

plot_segment2(radius, **style_radius)

plot_circle(add_element(circle(pts[-1], pts[2])))
plot_points(pts)

snapshot('01.square-01.png')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sgs = []
sgs.append(plot_segment(pts[0], pts[1]))
sgs.append(plot_segment(pts[1], pts[6]))
plot_points(pts)
sgs
# Out:
# ⎡     1   √5⎤
# ⎢1, - ─ + ──⎥
# ⎣     2   2 ⎦

# %%
snapshot('01.square-02.png')
