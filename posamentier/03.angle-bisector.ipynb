# %%
# %run ../run.py
# %matplotlib widget

# %%
square = unit_square(point(0, 0))
add_points(square.vertices)
polygons.append(square)

baseline = add_element(line(pts[0], pts[1]))

square = unit_square(pts[1])
add_points(square.vertices)
polygons.append(square)

square = unit_square(pts[4])
add_points(square.vertices)
polygons.append(square)

add_element(line(pts[0], pts[5]))
add_element(line(pts[4], pts[5]))

triangle = polygon_ids([0, 4, 5])
polygons.append(triangle)

bis = triangle.bisectors()[pts[5]]
l1 = add_element(line(bis.p1, bis.p2))

# %%
limx, limy = (-.5, 3.5), (-1.25, 2.25)
bounds = set_bounds(limx, limy)

plt_init(limx, limy)

plot_polygons(polygons)

plot_elements(elements, bounds)
plot_line(l1, bounds, linestyle='-.')

plot_points(pts)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sgs = []
sgs.append(plot_segment(pts[8], pts[4]))
sgs.append(plot_segment(pts[4], pts[6]))
plot_points(pts)
sgs
# Out:
# ⎡  1   √5   ⎤
# ⎢- ─ + ──, 1⎥
# ⎣  2   2    ⎦
