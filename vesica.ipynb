# %%
# %run setup2.py
# %matplotlib notebook

limx = (-3, 3)
limy = (-2.5, 2.5)
bounds = sp.Polygon(
    point(limx[0], limy[1]),
    point(limx[0], limy[0]),
    point(limx[1], limy[0]),
    point(limx[1], limy[1])
)

mpp_init(limx, limy)
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
begin()

bisector(pts[0], pts[1], bounds)
bisector(pts[0], pts[3], bounds)
bisector(pts[1], pts[2], bounds)

plot_points()
mpp.plot([-.5, .5], [0,0], color='#fc09', linestyle='-', linewidth=3, marker='o')
# Out:
# * add_point: Point2D(-1/2, 0)
#   +  Point2D(-1/2, 0)
# * add_point: Point2D(1/2, 0)
#   +  Point2D(1/2, 0)
# * add_element: Line2D(Point2D(-1/2, 0), Point2D(1/2, 0))
# * add_intersection_points: Line2D(Point2D(-1/2, 0), Point2D(1/2, 0))
#   + Line2D(Point2D(-1/2, 0), Point2D(1/2, 0))
# baseline: Line2D(Point2D(-1/2, 0), Point2D(1/2, 0))
# * add_element: Circle(Point2D(-1/2, 0), 1)
# * add_intersection_points: Circle(Point2D(-1/2, 0), 1)
# * add_point: Point2D(-3/2, 0)
#   +  Point2D(-3/2, 0)
# * add_point: Point2D(1/2, 0)
#   ! Point2D(1/2, 0) found at index: 1
#     > diff: -y**2 + y - (x + 1/2)**2 + 1
#   + Circle(Point2D(-1/2, 0), 1)
# * add_element: Circle(Point2D(1/2, 0), 1)
# * add_intersection_points: Circle(Point2D(1/2, 0), 1)
# * add_point: Point2D(-1/2, 0)
#   ! Point2D(-1/2, 0) found at index: 0
# * add_point: Point2D(3/2, 0)
#   +  Point2D(3/2, 0)
# * add_point: Point2D(0, -sqrt(3)/2)
#   +  Point2D(0, -sqrt(3)/2)
# * add_point: Point2D(0, sqrt(3)/2)
# ...

# %%
[(pt.x, pt.y) for pt in pts]
# Out:
# ⎡                                          ⎛   -√3 ⎞  ⎛   √3⎞                     ⎛   -√15 ⎞  ⎛   √15⎞            ⎛      -√15 ⎞  ⎛      √15⎞  ⎛   -√7 ⎞  ⎛   √7⎞
# ⎢(-1/2, 0), (1/2, 0), (-3/2, 0), (3/2, 0), ⎜0, ────⎟, ⎜0, ──⎟, (0, 0), (-5/2, 0), ⎜0, ─────⎟, ⎜0, ───⎟, (7/2, 0), ⎜-1/4, ─────⎟, ⎜-1/4, ───⎟, ⎜0, ────⎟, ⎜0, ──⎟, (1/2, √3), (1/2, -√3), (1/2, -1), (1/2, 1), (5/
# ⎣                                          ⎝    2  ⎠  ⎝   2 ⎠                     ⎝     2  ⎠  ⎝    2 ⎠            ⎝        4  ⎠  ⎝       4 ⎠  ⎝    2  ⎠  ⎝   2 ⎠
#
#        ⎛   -√15 ⎞  ⎛   √15⎞                                  ⎛     -√15 ⎞  ⎛     √15⎞  ⎛    -√15 ⎞  ⎛    √15⎞                                                                       ⎤
# 2, 0), ⎜1, ─────⎟, ⎜1, ───⎟, (1/2, -2), (1/2, 2), (-7/2, 0), ⎜1/4, ─────⎟, ⎜1/4, ───⎟, ⎜-1, ─────⎟, ⎜-1, ───⎟, (-1/2, √3), (-1/2, -√3), (-1/2, -1), (-1/2, 1), (-1/2, -2), (-1/2, 2)⎥
# ...

# %%
[[el.equation()] for el in elements]
# Out:
# ⎡     ⎡ 2            2    ⎤  ⎡ 2            2    ⎤       ⎡ 2            2    ⎤  ⎡ 2            2    ⎤             ⎡ 2            2    ⎤  ⎡ 2            2    ⎤           ⎤
# ⎣[y], ⎣y  + (x + 1/2)  - 1⎦, ⎣y  + (x - 1/2)  - 1⎦, [x], ⎣y  + (x + 1/2)  - 4⎦, ⎣y  + (x - 3/2)  - 4⎦, [x - 1/2], ⎣y  + (x - 1/2)  - 4⎦, ⎣y  + (x + 3/2)  - 4⎦, [x + 1/2]⎦

# %%
[[el.equation().simplify()] for el in elements]
# Out:
# ⎡     ⎡ 2        2   3⎤  ⎡ 2        2   3⎤       ⎡ 2        2   15⎤  ⎡ 2          2   7⎤             ⎡ 2        2   15⎤  ⎡ 2          2   7⎤           ⎤
# ⎢[y], ⎢x  + x + y  - ─⎥, ⎢x  - x + y  - ─⎥, [x], ⎢x  + x + y  - ──⎥, ⎢x  - 3⋅x + y  - ─⎥, [x - 1/2], ⎢x  - x + y  - ──⎥, ⎢x  + 3⋅x + y  - ─⎥, [x + 1/2]⎥
# ⎣     ⎣              4⎦  ⎣              4⎦       ⎣              4 ⎦  ⎣                4⎦             ⎣              4 ⎦  ⎣                4⎦           ⎦
