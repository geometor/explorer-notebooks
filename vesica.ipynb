# %%
# %run run.py
# %matplotlib widget
log_init('vesica')

# Build
start_time = timer()

begin()
bisector(pts[0], pts[1])

add_element(circle(pts[0], pts[3]))
add_element(circle(pts[1], pts[2]))

print(f'Build: {elapsed(start_time)}')
print()
print(f'elements: {len(elements)}')
print(f'  points: {len(pts)}')
# Out:
# Build: 0:00:02.632544
#
# elements: 6
#   points: 11

# %%
# Render
start_time = timer()

limx, limy = (-3.5, 3.5), (-2.5, 2.5)
bounds = set_bounds(limx, limy)

plt_init(limx, limy)

plot_elements(elements, bounds)
plot_points(pts)

print(f'Render: {elapsed(start_time)}')

snapshot('vesica-01.png')
# Out:
# Render: 0:00:00.656432
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.cla()

# %%
plt_init(limx, limy)

# %%
sgs = []
sgs.append(plot_segment(pts[9], pts[5]))
sgs.append(plot_segment(pts[5], pts[4]))
sgs.append(plot_segment(pts[4], pts[8]))

# %%
plot_elements(elements, bounds)
plot_points(pts)
snapshot('vesica-02.png')

# %%
ratios = []
ratios.append((sgs[0] / sgs[1]).simplify())
ratios.append((sgs[1] / sgs[2]).simplify())
ratios
[ratio - phi for ratio in ratios]
# Out:
# [-1, 0]

# %%
r = (sgs[1] / sgs[0])
r.simplify() - phi
# ((sgs[1] / sgs[0]) / phi).simplify()
# Out:
# 0

# %%
sp.srepr(pts[4])
# Out:
# 'Point2D(Integer(0), Mul(Integer(-1), Rational(1, 2), Pow(Integer(3), Rational(1, 2))))'

# %%
sg = segment(pts[4], pts[2])

sg.length
# Out:
# √3

# %%
sg.points
r = spg.Ray(pts[0], pts[5])

# %%
sg.angle_between(elements[0])
# Out:
# 5⋅π
# ───
#  6

# %%
# top equal
py = polygon([pts[0], pts[1], pts[5]])
py.angles[pts[0]]
# Out:
# π
# ─
# 3

# %%
py.vertices
# Out:
# (Point2D(-1/2, 0), Point2D(1/2, 0), Point2D(0, sqrt(3)/2))

# %%
plot_polygon(py)

# %%
[s.length for s in py.sides]
# Out:
# [1, 1, 1]

# %%
el = add_element(py.circumcircle)
plot_elements(elements, bounds)

# %%
lines = [el for el in elements if type(el) is sp.Line2D]
lines
# Out:
# [Line2D(Point2D(-1/2, 0), Point2D(1/2, 0)), Line2D(Point2D(0, sqrt(3)/2), Point2D(0, -sqrt(3)/2))]
