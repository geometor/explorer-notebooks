# %%
# %run setup2.py
# %matplotlib notebook

limx = (-3, 3)
limy = (-2.5, 2.5)
bounds = sp.Polygon(
    point(limx[0], limy[1]),
    point(limx[0], limy[0]),
    point(limx[1], limy[0]),
    point(limx[1], limy[1])
)

mpp_init(limx, limy)
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
#starting points
pt = point(sp.Rational(-1, 2), 0)
add_point(pt)
pt = point(sp.Rational(1, 2), 0)
add_point(pt)

# baseline
add_element(line(pts[0], pts[1]))
plot_line(elements[-1], bounds)

# vesica
add_element(circle(pts[0], pts[1]))
plot_circle(elements[-1])

add_element(circle(pts[1], pts[0]))
plot_circle(elements[-1])

# bisector
add_element(line(pts[4], pts[5]))
plot_line(elements[-1], bounds)

# add_element(circle(pts[2], pts[1]))
# plot_circle(elements[-1])

add_element(circle(pts[1], pts[2]))
plot_circle(elements[-1])

# add_element(line(pts[-1], pts[-2]))
# plot_line(elements[-1], bounds)

# add_element(circle(pts[3], pts[0]))
# plot_circle(elements[-1])

add_element(circle(pts[0], pts[3]))
plot_circle(elements[-1])

plot_points()
