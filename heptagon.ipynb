# %%
# %run lib/setup4
# %matplotlib notebook

limx = (-3, 3)
limy = (-2.5, 2.5)
bounds = sp.Polygon(
    point(limx[0], limy[1]),
    point(limx[0], limy[0]),
    point(limx[1], limy[0]),
    point(limx[1], limy[1])
)

# %%
p = sp.Polygon((0,0), 1, n=5)
p.vertices
# Out:
# [Point2D(1, 0), Point2D(-1/4 + sqrt(5)/4, sqrt(sqrt(5)/8 + 5/8)), Point2D(-sqrt(5)/4 - 1/4, sqrt(5/8 - sqrt(5)/8)), Point2D(-sqrt(5)/4 - 1/4, -sqrt(5/8 - sqrt(5)/8)), Point2D(-1/4 + sqrt(5)/4, -sqrt(sqrt(5)/8
# + 5/8))]

# %%
p.area
# Out:
#   25   5⋅√5
#   ── - ────
#   2     2
# ──────────────
#     __________
# 4⋅╲╱ 5 - 2⋅√5

# %%
p = sp.Polygon((0,0), 1, n=11)
p.vertices
# Out:
# [Point2D(1, 0), Point2D(cos(2*pi/11), sin(2*pi/11)), Point2D(cos(4*pi/11), sin(4*pi/11)), Point2D(-cos(5*pi/11), sin(5*pi/11)), Point2D(-cos(3*pi/11), sin(3*pi/11)), Point2D(-cos(pi/11), sin(pi/11)), Point2D(-
# cos(pi/11), -sin(pi/11)), Point2D(-cos(3*pi/11), -sin(3*pi/11)), Point2D(-cos(5*pi/11), -sin(5*pi/11)), Point2D(cos(4*pi/11), -sin(4*pi/11)), Point2D(cos(2*pi/11), -sin(2*pi/11))]

# %%
p.area
# Out:
#       2⎛π ⎞
# 11⋅sin ⎜──⎟
#        ⎝11⎠
# ───────────
#      ⎛π ⎞
#   tan⎜──⎟
#      ⎝11⎠

# %%
pts = p.vertices
pts[0].distance(pts[1])
# Out:
#      _____________________________
#     ╱               2
#    ╱  ⎛       ⎛2⋅π⎞⎞       2⎛2⋅π⎞
#   ╱   ⎜1 - cos⎜───⎟⎟  + sin ⎜───⎟
# ╲╱    ⎝       ⎝ 11⎠⎠        ⎝ 11⎠
