# %%
# %run run.py
# %matplotlib widget
log_init('vesica')

# Build
start_time = timer()

begin_zero()
bisector(pts[0], pts[1])

expr = x**2 - x - 1
roots = sp.solve(expr)
pr = [point(root, 0) for root in roots]
for pt in pr:
    add_point(pt)
    
add_point(point(0, 1))
add_element(circle(pts[6], pts[-1]))

print(f'Build: {elapsed(start_time)}')
# Out:
# Build: 0:00:00.932169

# %% [markdown]
# trying to marry sympy and matplotlib

# %%
start_time = timer()

limx, limy = (-3.5, 3.5), (-2.5, 2.5)
bounds = set_bounds(limx, limy)

plt_init(limx, limy)

expr2 = expr + 2
expr3 = expr + 2*x
expr4 = expr - 2*x**2 + 2*x + 2
expr5 = expr * x

# p = spp.plot(expr, aspect_ratio=(1,1))
p = spp.plot(expr, expr2, expr3, expr4, expr5, expr5 * x, aspect_ratio=(1,1), show=False)
p.xlim = limx
p.ylim = limy


p.show()

plot_elements(elements, bounds)
plot_points(pts)

# p.show()

print(f'Render: {elapsed(start_time)}')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Render: 0:00:00.393783
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_segment(pts[7], pts[8])
# Out:
# √5

# %%
sp.Parabola
# Out:
# sympy.geometry.parabola.Parabola

# %%
[expr.coeff(x, i) for i in reversed(range(3))]
# Out:
# [1, -1, -1]

# %%
expr = (expr * x).expand()
expr.powsimp()
# Out:
#  3    2
# x  - x  - x

# %%
[expr.coeff(x, i) for i in reversed(range(6))]
# Out:
# [0, 0, 1, -1, -1, 0]

# %%
sp.Expr
# Out:
# sympy.core.expr.Expr

# %%
import sympy.polys.polytools as sp_tools

# %%
p = sp_tools.Poly(x**2 - x - 1)

# %%
p.all_coeffs()
# Out:
# [1, -1, -1]

# %%
p.all_roots()
# Out:
# ⎡1   √5  1   √5⎤
# ⎢─ - ──, ─ + ──⎥
# ⎣2   2   2   2 ⎦

# %%
p.degree()
# Out:
# 2

# %%
px = sp_tools.Poly(x)
p = p.mul(px)
p.all_roots()
# Out:
# ⎡1   √5     1   √5⎤
# ⎢─ - ──, 0, ─ + ──⎥
# ⎣2   2      2   2 ⎦

# %%
p = p.mul(px)
p.all_roots()
# Out:
# ⎡1   √5        1   √5⎤
# ⎢─ - ──, 0, 0, ─ + ──⎥
# ⎣2   2         2   2 ⎦

# %%
a = 2
ex = a * x**2 + x + 1
pa = sp_tools.Poly(elements[1].equation())
pa.real_roots()
# Out:
# ---------------------------------------------------------------------------
# PolynomialError                           Traceback (most recent call last)
# /tmp/ipykernel_808874/2745921469.py in <module>
#       2 ex = a * x**2 + x + 1
#       3 pa = sp_tools.Poly(elements[1].equation())
# ----> 4 pa.real_roots()
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/polytools.py in real_roots(f, multiple, radicals)
#    3590
#    3591         """
# -> 3592         reals = sympy.polys.rootoftools.CRootOf.real_roots(f, radicals=radicals)
#    3593
#    3594         if multiple:
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/rootoftools.py in real_roots(cls, poly, radicals)
#     403     def real_roots(cls, poly, radicals=True):
#     404         """Get real roots of a polynomial. """
# --> 405         return cls._get_roots("_real_roots", poly, radicals)
#     406
#     407     @classmethod
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/rootoftools.py in _get_roots(cls, method, poly, radicals)
#     736         """Return postprocessed roots of specified kind. """
#     737         if not poly.is_univariate:
# --> 738             raise PolynomialError("only univariate polynomials are allowed")
#     739         # get rid of gen and it's free symbol
#     740         d = Dummy()
#
# PolynomialError: only univariate polynomials are allowed

# %%
(p.expr ).factor()

# %%
p.sqr()
