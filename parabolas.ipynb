# %%
# %run lib/setup6.py
# %matplotlib widget
# %pdb
log_init('vesica')

# Build
start_time = timer()

begin_zero()
bisector(pts[0], pts[1])

expr = x**2 - x - 1
roots = sp.solve(expr)
pr = [point(root, 0) for root in roots]
for pt in pr:
    add_point(pt)
    
add_point(point(0, 1))
add_element(circle(pts[6], pts[-1]))

print(f'Build: {elapsed(start_time)}')
# Out:
# Build: 0:00:01.052594

# %% [markdown]
# trying to marry sympy and matplotlib

# %%
start_time = timer()

limx, limy = (-3.5, 3.5), (-2.5, 2.5)
bounds = set_bounds(limx, limy)

plt_init(limx, limy)

expr2 = expr + 2
expr3 = expr + 2*x
expr4 = expr - 2*x**2 + 2*x + 2
expr5 = expr * x

# p = spp.plot(expr, aspect_ratio=(1,1))
p = spp.plot(expr, expr2, expr3, expr4, expr5, expr5 * x, aspect_ratio=(1,1), show=False)
p.xlim = limx
p.ylim = limy


p.show()

plot_elements(elements, bounds)
plot_points(pts)

# p.show()

print(f'Render: {elapsed(start_time)}')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Render: 0:00:00.329031

# %%
plot_segment(pts[7], pts[8])
# Out:
# √5

# %%
sp.Parabola
# Out:
# Init signature: sp.Parabola(focus=None, directrix=None, **kwargs)
# Docstring:
# A parabolic GeometryEntity.
#
# A parabola is declared with a point, that is called 'focus', and
# a line, that is called 'directrix'.
# Only vertical or horizontal parabolas are currently supported.
#
# Parameters
# ==========
#
# focus : Point
#     Default value is Point(0, 0)
# directrix : Line
#
# Attributes
# ==========
#
# focus
# directrix
# axis of symmetry
# focal length
# p parameter
# vertex
# eccentricity
#
# Raises
# ======
# ValueError
#     When `focus` is not a two dimensional point.
#     When `focus` is a point of directrix.
# NotImplementedError
#     When `directrix` is neither horizontal nor vertical.
#
# Examples
# ========
#
# >>> from sympy import Parabola, Point, Line
# >>> p1 = Parabola(Point(0, 0), Line(Point(5, 8), Point(7,8)))
# >>> p1.focus
# Point2D(0, 0)
# >>> p1.directrix
# Line2D(Point2D(5, 8), Point2D(7, 8))
# File:           ~/anaconda3/lib/python3.9/site-packages/sympy/geometry/parabola.py
# Type:           ManagedProperties
# Subclasses:

# %%
[expr.coeff(x, i) for i in reversed(range(3))]
# Out:
# [1, -1, -1]

# %%
expr = (expr * x).expand()
expr.powsimp()
# Out:
#  6    5    4
# x  - x  - x

# %%
[expr.coeff(x, i) for i in reversed(range(6))]
# Out:
# [1, -1, -1, 0, 0, 0]

# %%
# Out:
# ⎛ 4    2    3⎞
# ⎝x , -x , -x ⎠

# %%
sp.Expr
# Out:
# sympy.core.expr.Expr

# %%
import sympy.polys.polytools as sp_tools

# %%
sp_tools.P
# Out:
# Signature: sp_tools.compose(f, g, *gens, **args)
# Docstring:
# Compute functional composition ``f(g)``.
#
# Examples
# ========
#
# >>> from sympy import compose
# >>> from sympy.abc import x
#
# >>> compose(x**2 + x, x - 1)
# x**2 - x
# File:      ~/anaconda3/lib/python3.9/site-packages/sympy/polys/polytools.py
# Type:      function
