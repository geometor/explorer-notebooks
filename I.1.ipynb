# %%
# %run /home/phi/Notebooks/geometor-explorer/lib/setup6.py

# %matplotlib widget

# build
begin()

# bisector(pts[0], pts[1])
add_element(line(pts[0], pts[1]))
add_element(circle(pts[0], pts[1]))
add_element(circle(pts[1], pts[0]))

# render
limx, limy = (-2, 2), (-1.5, 1.5)
bounds = set_bounds(limx, limy)

plt_init(limx, limy)

plot_polygon(polygon([pts[0], pts[1], pts[5]]))

plot_elements(elements, bounds)
plot_points(pts)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.cla()
plt_init(limx, limy)
plot_elements(elements, bounds)
plot_points(pts)

# %%
add_element(line(pts[0], pts[4]))
add_element(line(pts[0], pts[5]))
add_element(line(pts[1], pts[4]))
add_element(line(pts[1], pts[5]))

                     

plot_elements(elements, bounds)
plot_points(pts)

# %%
add_element(line(pts[4], pts[5]))
add_element(line(pts[0], pts[8]))
add_element(line(pts[1], pts[6]))

plot_elements(elements, bounds)
plot_points(pts)

# %%
poly_pts = [pts[i] for i in [0, 1, 4]]

# %%
poly_pts
# Out:
# [Point2D(-1/2, 0), Point2D(1/2, 0), Point2D(0, -sqrt(3)/2)]

# %%
py = polygon(poly_pts)

# %%
plot_polygon(py)

# %%
c = add_element(circle(pts[14], pts[4]))
plot_circle(c)
plot_points(pts)

# %%
sg_pts = [pts[i] for i in [18, 0, 1, 19]]
p = polygon(poly_pts)
sgs = []


sg_pts[0:-1]

[(sg_pts[i], sg_pts[i+1]) for i in range(len(sg_pts)-1)]
# Out:
# [(Point2D(-sqrt(5)/2, 0), Point2D(-1/2, 0)), (Point2D(-1/2, 0), Point2D(1/2, 0)), (Point2D(1/2, 0), Poi
# nt2D(sqrt(5)/2, 0))]

# %%
fig, *axs = plt.subplots(nrows=2, ncols=2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ax1 = plt.subplot(1, 1, 1)

# %%
ax1.axis(False)
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
ax1.set_title('1')
# Out:
# Text(0.5, 1.0, '1')

# %%
t = polygon_ids([0, 1, 5])

# %%
t.area
# Out:
# √3
# ──
# 4

# %%
plot_polygon(t)

# %%
wd_pts = [pts[i] for i in [0, 1, 5]]
plot
